# %%
import numpy as np

# %% [markdown]
# Step 1: Input Embeddings

# %%
X = np.array([
    [1, 0, 1],   # Dog
    [0, 1, 1],   # Chasing
    [1, 1, 0]    # Cat
])

print("Input Embeddings (X):\n", X)
# Out:
# Input Embeddings (X):
#  [[1 0 1]
#  [0 1 1]
#  [1 1 0]]

# %% [markdown]
# Step 2: Weight Matrices

# %%
W_Q = np.eye(3)
W_K = np.eye(3)
W_V = np.eye(3)

Q = X @ W_Q
K = X @ W_K
V = X @ W_V

# %% [markdown]
# Step 3: Calculate Attention Scores

# %%
scores = Q @ K.T
print("Attention Scores:\n", scores)
# Out:
# Attention Scores:
#  [[2. 1. 1.]
#  [1. 2. 1.]
#  [1. 1. 2.]]

# %% [markdown]
# Step 4: Scaling + Softmax

# %%
d_k = K.shape[1]
scaled_scores = scores / np.sqrt(d_k)

def softmax(x):
    exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
    return exp_x / np.sum(exp_x, axis=1, keepdims=True)

attention_weights = softmax(scaled_scores)
print("\nAttention Weights (after softmax):\n", attention_weights)
# Out:
# Attention Weights (after softmax):
#  [[0.47108308 0.26445846 0.26445846]
#  [0.26445846 0.47108308 0.26445846]
#  [0.26445846 0.26445846 0.47108308]]

# %% [markdown]
# Step 5: Final Output

# %%
output = attention_weights @ V
print("Final Output (New Representations):\n", output)
# Out:
# Final Output (New Representations):
#  [[0.73554154 0.52891692 0.73554154]
#  [0.52891692 0.73554154 0.73554154]
#  [0.73554154 0.73554154 0.52891692]]
